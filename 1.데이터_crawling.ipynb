# %%
import pandas as pd
from selenium import webdriver
import time
import re
import csv
import time
from selenium.webdriver.common.keys import Keys
import warnings 
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2456f45c477d> in <module>
#       1 import pandas as pd
# ----> 2 from selenium import webdriver
#       3 import time
#       4 import re
#       5 import csv
#
# ModuleNotFoundError: No module named 'selenium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# 기본 사이트 들어오기
url = 'https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=100000100020006&fltDispCatNo=&prdSort=01&pageIdx=2&rowsPerPage=24&searchTypeSort=btn_thumb&plusButtonFlag=N&isLoginCnt=0&aShowCnt=&bShowCnt=&cShowCnt=&trackingCd=Cat100000100020006_Small'
driver = webdriver.Chrome("C:/Users/User/Desktop/rec/chromedriver_win32/chromedriver.exe")
driver.implicitly_wait(3)
driver.get(url)

# %%
# 빈 레이어 정의 
user_id=[]
user_rank=[]
user_type=[]
user_type2=[]

star=[]
write_date=[]

rate_1=[]
rate_2=[]
rate_3=[]
rate_4=[]

item_option=[]
item_name=[]

# %%
# 중간부분 수정
for i in range(2, 5):
    #driver.find_element_by_xpath('//*[@id="Contents"]/div[1]/ul/li[2]/div/ul/li[1]/a').click()
    #driver.find_element_by_xpath('//*[@id="Container"]/div[2]/a[1]' ).click()
    #driver.find_element_by_xpath('//*[@id="Contents"]/div[5]/div[2]/ul/li[3]').click()
    for j in range(1, 5):
        i = str(i)
        j = str(j)
        driver.find_element_by_xpath('//*[@id="Contents"]/ul['+i+']/li['+j+']/div/a').click()
        driver.find_element_by_xpath('//*[@id="reviewInfo"]/a').click()
        for p in range(1, 10):
            try:
                p = str(p)
                for k in range(1, 11):
                    item_name.append(driver.find_element_by_xpath(
                        '//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text)
                    k = str(k)
                    try:
                        user_id.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[1]/div/p[1]/a[1]').text)
                        user_rank.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[1]/div/p[1]/a[2]').text)
                        user_type.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[1]/div/p[2]').text)
                        user_type2.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[1]/div/p[3]').text)                        
                        star.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[1]/span[1]').text)

                        write_date.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[1]/span[2]').text)
                        rate_1.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[1]/dd/span').text)
                        rate_2.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[2]/dd/span').text)
                        rate_3.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[3]/dd/span').text)
                        rate_4.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[4]/dd/span').text)
                        item_option.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/p').text)
                    except:
                        #user_id.append("")
                        user_rank.append("")
                        user_type.append("")
                        user_type2.append("")
                        #star.append("")
                        #write_date.append("")
                        #rate_1.append("")
                        #rate_2.append("")
                        #rate_3.append("")               
                        #rate_4.append("")
                                               
                        star.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[1]/span[1]').text)

                        write_date.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[1]/span[2]').text)
                        rate_1.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[1]/dd/span').text)
                        rate_2.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[2]/dd/span').text)
                        rate_3.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[3]/dd/span').text)
                        rate_4.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[4]/dd/span').text)
                        item_option.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/p').text)
                driver.find_element_by_xpath('//*[@id="gdasContentsArea"]/div/div[8]/a['+p+']').click()
            except:
                driver.find_element_by_xpath('//*[@id="btnGnbOpen"]' ).click()
                driver.find_element_by_xpath('//*[@id="gnbAllMenu"]/ul/li[1]/div[2]/ul[2]/li[1]/a' ).click()
                driver.find_element_by_xpath('//*[@id="Container"]/div[2]/a[1]' ).click()
        driver.find_element_by_xpath('//*[@id="btnGnbOpen"]' ).click()
        driver.find_element_by_xpath('//*[@id="gnbAllMenu"]/ul/li[1]/div[2]/ul[2]/li[1]/a' ).click()
        driver.find_element_by_xpath('//*[@id="Container"]/div[2]/a[1]' ).click()

# %%
for i in range(2, 13):
    #driver.find_element_by_xpath('//*[@id="Contents"]/div[1]/ul/li[2]/div/ul/li[1]/a').click()
    #driver.find_element_by_xpath('//*[@id="Container"]/div[2]/a[1]' ).click()
    #driver.find_element_by_xpath('//*[@id="Contents"]/div[5]/div[2]/ul/li[3]').click()
    for j in range(1, 5):
        i = str(i)
        j = str(j)
        driver.find_element_by_xpath('//*[@id="Contents"]/ul['+i+']/li['+j+']/div/a').click()
        driver.find_element_by_xpath('//*[@id="reviewInfo"]/a').click()
        for p in range(1, 10):
            try:
                p = str(p)
                for k in range(1, 11):
                    item_name.append(driver.find_element_by_xpath(
                        '//*[@id="Contents"]/div[2]/div[2]/div/p[2]').text)
                    k = str(k)
                    try:
                        user_id.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[1]/div/p[1]/a[1]').text)
                        user_rank.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[1]/div/p[1]/a[2]').text)
                        user_type.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[1]/div/p[2]').text)
                        user_type2.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[1]/div/p[3]').text)                        
                        star.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[1]/span[1]').text)

                        write_date.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[1]/span[2]').text)
                        rate_1.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[1]/dd/span').text)
                        rate_2.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[2]/dd/span').text)
                        rate_3.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[3]/dd/span').text)
                        rate_4.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[4]/dd/span').text)
                        item_option.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/p').text)
                    except:
                        #user_id.append("")
                        user_rank.append("")
                        user_type.append("")
                        user_type2.append("")
                        #star.append("")
                        #write_date.append("")
                        #rate_1.append("")
                        #rate_2.append("")
                        #rate_3.append("")               
                        #rate_4.append("")
                                               
                        star.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[1]/span[1]').text)

                        write_date.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[1]/span[2]').text)
                        rate_1.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[1]/dd/span').text)
                        rate_2.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[2]/dd/span').text)
                        rate_3.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[3]/dd/span').text)
                        rate_4.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/div[2]/dl[4]/dd/span').text)
                        item_option.append(driver.find_element_by_xpath('//*[@id="gdasList"]/li['+k+']/div[2]/p').text)
                driver.find_element_by_xpath('//*[@id="gdasContentsArea"]/div/div[8]/a['+p+']').click()
            except:
                driver.find_element_by_xpath('//*[@id="btnGnbOpen"]' ).click()
                driver.find_element_by_xpath('//*[@id="gnbAllMenu"]/ul/li[1]/div[2]/ul[2]/li[1]/a' ).click()
                driver.find_element_by_xpath('//*[@id="Contents"]/div[5]/div[2]/ul/li[3]/a' ).click()
        driver.find_element_by_xpath('//*[@id="btnGnbOpen"]' ).click()
        driver.find_element_by_xpath('//*[@id="gnbAllMenu"]/ul/li[1]/div[2]/ul[2]/li[1]/a' ).click()
        driver.find_element_by_xpath('//*[@id="Contents"]/div[5]/div[2]/ul/li[3]/a' ).click()

# %%
df2=pd.DataFrame([user_id, item_name, item_option, user_rank, user_type, star, write_date, rate_1, rate_2, rate_3, rate_4])

# %%
df2=df2.T

# %%
df2
# Out:
#           0                               1   \
# 0         맹두                 오브제 무드체인지 립밤 3g
# 1    올영알바생도비  [1+1] 크리니크 처비스틱 립 컬러 밤 (웜톤/쿨톤)
# 2        Zen  [1+1] 크리니크 처비스틱 립 컬러 밤 (웜톤/쿨톤)
# 3      루나key  [1+1] 크리니크 처비스틱 립 컬러 밤 (웜톤/쿨톤)
# 4    Jenny17  [1+1] 크리니크 처비스틱 립 컬러 밤 (웜톤/쿨톤)
# ..       ...                             ...
# 384     None                            None
# 385     None                            None
# 386     None                            None
# 387     None                            None
# 388     None                            None
#
#                                                     2         3   \
# 0                                [옵션] 쿨톤(수퍼스트로베리+커비캔디)    TOP 43
# 1                                [옵션] 쿨톤(수퍼스트로베리+커비캔디)
# 2                                [옵션] 쿨톤(수퍼스트로베리+커비캔디)   TOP 554
# 3    * 본 상품 후기는 올영체험단으로 선정되어 CJ올리브영으로부터 위 상품을 무료로 제...
# 4    * 본 상품 후기는 올영체험단으로 선정되어 CJ올리브영으로부터 위 상품을 무료로 제...    TOP 86
# ...

# %%
df2.columns
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
df2.columns=[['user_id', 'item_name', 'item_option', 'user_rank', 'user_type', 'star', 'write_date', 'rate_1', 
             'rate_2', 'rate_3', 'rate_4']]

# %%
df2.to_excel(excel_writer='sample4.xlsx')
